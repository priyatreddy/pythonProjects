# %%
import pandas as pd
disney = pd.read_csv(r"C:\Users\student\Downloads\disney_movies.csv")
#disney.info()
disney
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
import pyodbc as py

conn = py.connect('Driver={ODBC Driver 17 for SQL Server};'
                  'Server=localhost;'
                  'database=Priyaweek5Lab;'
                  'trusted_connection=yes;'
                  )
cursor = conn.cursor()
cursor.execute('select @@version;')
row = cursor.fetchone()
while row:
    print(row[0])
    row=cursor.fetchone()
# Out:
# Microsoft SQL Server 2019 (RTM-GDR) (KB4583458) - 15.0.2080.9 (X64)
# 	Nov  6 2020 16:50:01
# 	Copyright (C) 2019 Microsoft Corporation
# 	Developer Edition (64-bit) on Windows Server 2019 Datacenter 10.0 <X64> (Build 17763: ) (Hypervisor)

# %%
import pandas as pd
disney = pd.read_csv(r"C:\Users\student\Downloads\disney_movies.csv")

#below we are defining the dataframe for our file
df = pd.DataFrame(disney)

#Below we are filling 0 with null values
df = df.fillna(0)

import pyodbc as py

conn = py.connect('Driver={ODBC Driver 17 for SQL Server};'
                  'Server=localhost;'
                  'database=Priyaweek5Lab;'
                  'trusted_connection=yes;'
                  )
# cursor = conn.cursor()
    
# for row in df.itertuples():
#    cursor.execute('''
#                INSERT INTO [dbo].[disney_movies] (movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross)
#                VALUES (?,?,?,?,?,?)
#                ''',
#                row.movie_title,
#                row.release_date,
#                 row.genre,
#                 row.mpaa_rating,
#                 row.total_gross,
#                 row.inflation_adjusted_gross
#                 )
# conn.commit()

selectquery = "select * from [dbo].[disney_movies]"

dg = pd.read_sql(selectquery,conn)

# We can see top 25 rows below
dg.head(25)
# Out:
#                                movie_title release_date      genre  \
# 0          Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1                                Pinocchio   1940-02-09  Adventure
# 2                                 Fantasia   1940-11-13    Musical
# 3                        Song of the South   1946-11-12  Adventure
# 4                               Cinderella   1950-02-15      Drama
# 5             20,000 Leagues Under the Sea   1954-12-23  Adventure
# 6                       Lady and the Tramp   1955-06-22      Drama
# 7                          Sleeping Beauty   1959-01-29      Drama
# 8                           101 Dalmatians   1961-01-25     Comedy
# 9              The Absent Minded Professor   1961-03-16     Comedy
# 10                        Babes in Toyland   1961-12-14    Musical
# 11                             Bon Voyage!   1962-05-17     Comedy
# 12                  The Sword in the Stone   1963-12-25  Adventure
# ...
